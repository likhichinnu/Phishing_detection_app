# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
pip install whois
# Out:
# Collecting whois
#   Downloading https://files.pythonhosted.org/packages/40/f0/d2e038bd54a8c95a4240a322682accd4cb2a1d5f298c40aed9e881d63641/whois-0.9.7.tar.gz
# Building wheels for collected packages: whois
#   Building wheel for whois (setup.py) ... done
#   Created wheel for whois: filename=whois-0.9.7-cp36-none-any.whl size=8888 sha256=8465a562082392baa6c17ea8dbd1b7e391639c8269e0a905e1ed952a62450635
#   Stored in directory: /root/.cache/pip/wheels/56/4c/53/02bc75ef02bd738b5ee9ece5bd61f86ba25c543aebca583cd2
# Successfully built whois
# Installing collected packages: whois
# Successfully installed whois-0.9.7

# %%
# packages
import pandas as pd
from urllib.parse import urlparse,urlencode
import re
from bs4 import BeautifulSoup
import requests
import whois
import urllib.request
from datetime import datetime
import time
import socket
from urllib.error import HTTPError
from cython.parallel import prange

# %%
from datetime import datetime
itime = datetime.now()
for i in prange(0,10000):
    pass
ftime = datetime.now()
print(ftime-itime)
# Out:
# 0:00:00.000761

# %%
computer_raw_data=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Phishing-Website-Detection-master/raw_datasets/legitimate_urls.txt",header=None,names=["urls"])
computer_raw_data.head(10)
# Out:
#                                                 urls
# 0                   http://www.liquidgeneration.com/
# 1                        http://www.onlineanime.org/
# 2  http://www.ceres.dti.ne.jp/~nekoi/senno/senfir...
# 3                         http://www.galeon.com/kmh/
# 4                        http://www.fanworkrecs.com/
# 5                         http://www.animehouse.com/
# 6         http://www2.117.ne.jp/~mb1996ax/enadc.html
# 7    http://archive.rhps.org/fritters/yui/index.html
# 8                     http://www.freecartoonsex.com/
# 9                            http://www.cutepet.org/

# %%
computer_raw_data["urls"][0]
# Out:
# 'http://www.liquidgeneration.com/'

# %%
cd = None
class FeatureExtraction:
    def __init__(self):
        pass
    
    def getProtocol(self,url):
        return urlparse(url).scheme
    
    def getDomain(self,url):
        return urlparse(url).netloc
    
    def getPath(self,url):
        return urlparse(url).path
    
    def havingIP(self,url):
        """If the domain part has IP then it is phishing otherwise legitimate"""
        match=re.search('(([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\.([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\.([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\.([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\/)|'  #IPv4
                    '((0x[0-9a-fA-F]{1,2})\\.(0x[0-9a-fA-F]{1,2})\\.(0x[0-9a-fA-F]{1,2})\\.(0x[0-9a-fA-F]{1,2})\\/)'  #IPv4 in hexadecimal
                    '(?:[a-fA-F0-9]{1,4}:){7}[a-fA-F0-9]{1,4}',url)     #Ipv6
        if match:
            #print match.group()
            return 1            # phishing
        else:
            #print 'No matching pattern found'
            return 0            # legitimate
    
    def long_url(self,url):
        """This function is defined in order to differntiate website based on the length of the URL"""
        if len(url) < 54:
            return 0            # legitimate
        elif len(url) >= 54 and len(url) <= 75:
            return 2            # suspicious
        else:
            return 1            # phishing
    
    def have_at_symbol(self,url):
        """This function is used to check whether the URL contains @ symbol or not"""
        if "@" in url:
            return 1            # phishing
        else:
            return 0            # legitimate
    
    def redirection(self,url):
        """If the url has symbol(//) after protocol then such URL is to be classified as phishing """
        if "//" in urlparse(url).path:
            return 1            # phishing
        else:
            return 0            # legitimate
        
    def prefix_suffix_separation(self,url):
        """If the domain has '-' symbol then it is considered as phishing site"""
        if "-" in urlparse(url).netloc:
            return 1            # phishing
        else:
            return 0            # legitimate
        
    def sub_domains(self,url):
        """If the url has more than 3 dots then it is a phishing"""
        if url.count(".") < 3:
            return 0            # legitimate
        elif url.count(".") == 3:
            return 2            # suspicious
        else:
            return 1            # phishing
        
    def shortening_service(self,url):
        """Tiny URL -> phishing otherwise legitimate"""
        match=re.search('bit\.ly|goo\.gl|shorte\.st|go2l\.ink|x\.co|ow\.ly|t\.co|tinyurl|tr\.im|is\.gd|cli\.gs|'
                    'yfrog\.com|migre\.me|ff\.im|tiny\.cc|url4\.eu|twit\.ac|su\.pr|twurl\.nl|snipurl\.com|'
                    'short\.to|BudURL\.com|ping\.fm|post\.ly|Just\.as|bkite\.com|snipr\.com|fic\.kr|loopt\.us|'
                    'doiop\.com|short\.ie|kl\.am|wp\.me|rubyurl\.com|om\.ly|to\.ly|bit\.do|t\.co|lnkd\.in|'
                    'db\.tt|qr\.ae|adf\.ly|goo\.gl|bitly\.com|cur\.lv|tinyurl\.com|ow\.ly|bit\.ly|ity\.im|'
                    'q\.gs|is\.gd|po\.st|bc\.vc|twitthis\.com|u\.to|j\.mp|buzurl\.com|cutt\.us|u\.bb|yourls\.org|'
                    'x\.co|prettylinkpro\.com|scrnch\.me|filoops\.info|vzturl\.com|qr\.net|1url\.com|tweez\.me|v\.gd|tr\.im|link\.zip\.net',url)
        if match:
            return 1               # phishing
        else:
            return 0               # legitimate
        
    """
    def google_index(self,url):
        user_agent = 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/48.0.2564.116 Safari/537.36'
        headers = { 'User-Agent' : user_agent}
        query = {'q': 'info:' + url}
        google = "https://www.google.com/search?" + urlencode(query)
        #data = requests.get(google, headers=headers,proxies=proxies)
        data = requests.get(google,headers=headers)
        data.encoding = 'ISO-8859-1'
        soup = BeautifulSoup(str(data.content), "html.parser")
        try:
            check = soup.find(id="rso").find("div").find("div").find("h3").find("a")
            if soup.find(id="rso").find("div").find("div").find("h3").find("a").find("href" != None):
                href = check['href']
                return 0 # indexed
            else:
                return 1
        except AttributeError:
            return 1 # indexed
        #print("Waiting " + str(seconds) + " seconds until checking next URL.\n")
        #time.sleep(float(seconds))
    """
    """
    def abnormal_url(self,url):
        dns = 0
        #domain_name = ""
        try:
            #domain = urlparse(url).netloc
            #print(domain)
            domain_name = whois.whois(urlparse(url).netloc)
            #print(domain_name)
        except:
            dns = 1
        
        if dns == 1:
            return 1 # phishing
        else:
            hostname=domain_name.domain_name
            #match=re.search(hostname,url)
            if hostname in url:
                return 0 # legitimate
            else:
                return 1 # phishing
    """
    
    def web_traffic(self,url):
        try:
            rank = BeautifulSoup(urllib.request.urlopen("http://data.alexa.com/data?cli=10&dat=s&url=" + url).read(), "xml").find("REACH")['RANK']
        except TypeError:
            return 1
        except HTTPError:
            return 2
        rank= int(rank)
        if (rank<100000):
            return 0
        else:
            return 2
        
    def domain_registration_length(self,url):
        dns = 0
        try:
            domain_name = whois.whois(urlparse(url).netloc)
        except:
            dns = 1
        
        if dns == 1:
            return 1      #phishing
        else:
            expiration_date = domain_name.expiration_date
            today = time.strftime('%Y-%m-%d')
            today = datetime.strptime(today, '%Y-%m-%d')
            if expiration_date is None:
                return 1
            elif type(expiration_date) is list or type(today) is list :
                return 2     #If it is a type of list then we can't select a single value from list. So,it is regarded as suspected website  
            else:
                creation_date = domain_name.creation_date
                expiration_date = domain_name.expiration_date
                if (isinstance(creation_date,str) or isinstance(expiration_date,str)):
                    try:
                        creation_date = datetime.strptime(creation_date,'%Y-%m-%d')
                        expiration_date = datetime.strptime(expiration_date,"%Y-%m-%d")
                    except:
                        return 2
                registration_length = abs((expiration_date - today).days)
                if registration_length / 365 <= 1:
                    return 1 #phishing
                else:
                    return 0 # legitimate
            
    def age_domain(self,url):
        dns = 0
        try:
            domain_name = whois.whois(urlparse(url).netloc)
        except:
            dns = 1
        
        if dns == 1:
            return 1
        else:
            creation_date = domain_name.creation_date
            expiration_date = domain_name.expiration_date
            if (isinstance(creation_date,str) or isinstance(expiration_date,str)):
                try:
                    creation_date = datetime.strptime(creation_date,'%Y-%m-%d')
                    expiration_date = datetime.strptime(expiration_date,"%Y-%m-%d")
                except:
                    return 2
            if ((expiration_date is None) or (creation_date is None)):
                return 1
            elif ((type(expiration_date) is list) or (type(creation_date) is list)):
                return 2
            else:
                ageofdomain = abs((expiration_date - creation_date).days)
                if ((ageofdomain/30) < 6):
                    return 1
                else:
                    return 0
     
    
    def dns_record(self,url):
        dns = 0
        try:
            domain_name = whois.whois(urlparse(url).netloc)
            #rint(domain_name)
        except:
            dns = 1
        
        if dns == 1:
            return 1
        else:
            return 0
        
   
    def statistical_report(self,url):
        hostname = url
        h = [(x.start(0), x.end(0)) for x in re.finditer('https://|http://|www.|https://www.|http://www.', hostname)]
        z = int(len(h))
        if z != 0:
            y = h[0][1]
            hostname = hostname[y:]
            h = [(x.start(0), x.end(0)) for x in re.finditer('/', hostname)]
            z = int(len(h))
            if z != 0:
                hostname = hostname[:h[0][0]]
        url_match=re.search('at\.ua|usa\.cc|baltazarpresentes\.com\.br|pe\.hu|esy\.es|hol\.es|sweddy\.com|myjino\.ru|96\.lt|ow\.ly',url)
        try:
            ip_address = socket.gethostbyname(hostname)
            ip_match=re.search('146\.112\.61\.108|213\.174\.157\.151|121\.50\.168\.88|192\.185\.217\.116|78\.46\.211\.158|181\.174\.165\.13|46\.242\.145\.103|121\.50\.168\.40|83\.125\.22\.219|46\.242\.145\.98|107\.151\.148\.44|107\.151\.148\.107|64\.70\.19\.203|199\.184\.144\.27|107\.151\.148\.108|107\.151\.148\.109|119\.28\.52\.61|54\.83\.43\.69|52\.69\.166\.231|216\.58\.192\.225|118\.184\.25\.86|67\.208\.74\.71|23\.253\.126\.58|104\.239\.157\.210|175\.126\.123\.219|141\.8\.224\.221|10\.10\.10\.10|43\.229\.108\.32|103\.232\.215\.140|69\.172\.201\.153|216\.218\.185\.162|54\.225\.104\.146|103\.243\.24\.98|199\.59\.243\.120|31\.170\.160\.61|213\.19\.128\.77|62\.113\.226\.131|208\.100\.26\.234|195\.16\.127\.102|195\.16\.127\.157|34\.196\.13\.28|103\.224\.212\.222|172\.217\.4\.225|54\.72\.9\.51|192\.64\.147\.141|198\.200\.56\.183|23\.253\.164\.103|52\.48\.191\.26|52\.214\.197\.72|87\.98\.255\.18|209\.99\.17\.27|216\.38\.62\.18|104\.130\.124\.96|47\.89\.58\.141|78\.46\.211\.158|54\.86\.225\.156|54\.82\.156\.19|37\.157\.192\.102|204\.11\.56\.48|110\.34\.231\.42',ip_address)  
        except:
            return 1

        if url_match:
            return 1
        else:
            return 0
        
    def https_token(self,url):
        match=re.search('https://|http://',url)
        try:
            if match.start(0)==0 and match.start(0) is not None:
                url=url[match.end(0):]
                match=re.search('http|https',url)
                if match:
                    return 1
                else:
                    return 0
        except:
            return 1

# %%
#features
protocol = []
domain = []
path = []
having_ip = []
len_url = []
having_at_symbol = []
redirection_symbol = []
prefix_suffix_separation = []
sub_domains = []
tiny_url = []
abnormal_url = []
web_traffic = []
domain_registration_length = []
dns_record = []
statistical_report = []
age_domain = []
http_tokens = []
#google_index = []

# %% [markdown]
# ### 0 - legitimate
# ### 1 - phishing
# ### 2 - suspicious

# %%
# object creation
fe = FeatureExtraction()
rows = len(computer_raw_data["urls"])

for i in range(0,rows):
    url=computer_raw_data["urls"][i]
    print(i ),print(url)
    protocol.append(fe.getProtocol(url))
    path.append(fe.getPath(url))
    domain.append(fe.getDomain(url))
    having_ip.append(fe.havingIP(url))
    len_url.append(fe.long_url(url))
    having_at_symbol.append(fe.have_at_symbol(url))
    redirection_symbol.append(fe.redirection(url))
    prefix_suffix_separation.append(fe.prefix_suffix_separation(url))
    sub_domains.append(fe.sub_domains(url))
    tiny_url.append(fe.shortening_service(url))
    web_traffic.append(fe.web_traffic(url))
    domain_registration_length.append(fe.domain_registration_length(url))
    dns_record.append(fe.dns_record(url))
    statistical_report.append(fe.statistical_report(url))
    age_domain.append(fe.age_domain(url))
    http_tokens.append(fe.https_token(url))
    #google_index.append(fe.google_index(url))
    #abnormal_url.append(fe.abnormal_url(url))
    
#print(domain)
#print(protocol)
#print(ip)
#print(len_url)
#print(google_index)
#print(abnormal_url)
#print(web_traffic)
#print(domain_registration_length)
#print(age_domain)
#print(dns_record)
#print(statistical_report)
# Out:
# 0
# http://www.liquidgeneration.com/
# 1
# http://www.onlineanime.org/
# 2
# http://www.ceres.dti.ne.jp/~nekoi/senno/senfirst.html
# 3
# http://www.galeon.com/kmh/
# 4
# http://www.fanworkrecs.com/
# 5
# http://www.animehouse.com/
# 6
# http://www2.117.ne.jp/~mb1996ax/enadc.html
# 7
# http://archive.rhps.org/fritters/yui/index.html
# 8
# http://www.freecartoonsex.com/
# 9
# http://www.cutepet.org/
# 10
# http://www.taremeparadise.com/
# 11
# http://www.internetdump.com/users/pornographite/index1.html
# 12
# http://darkkaminari.net
# 13
# http://www.iei.net/~bkos1/velneko.htm
# 14
# http://www9.kinghost.com/fetish/hentaibee/
# 15
# http://www.jasonmeador.com/
# 16
# http://www.geocities.com/kaseychan17/index.html
# 17
# http://www.angelfire.com/journal/coldlemonade/index.html
# 18
# http://e.webring.com/hub?sid=&amp;ring=hentff98&amp;id=&amp;list
# 19
# http://www.nemurokinenkan.net
# 20
# http://j-heaven.tripod.com/library.htm
# 21
# http://www.angelfire.com/poetry/nicolesstories/
# 22
# http://thesheeparecoming.tripod.com/papercrane/
# 23
# http://www.geocities.com/eddie_monsoon2002/
# 24
# http://www.shokushu.com/
# 25
# http://www.geocities.com/timessquare/arcade/7810/p_hgames.htm
# 26
# http://www.hentaisocialclub.com/ganguro/index.html
# 27
# http://ryogamasaki.netfirms.com/
# 28
# http://members.tripod.com/~chaz16/3.html
# 29
# http://www.hentai-comics.com/
# 30
# http://www.jastusa.com/
# 31
# http://www.peachprincess.com/
# 32
# http://www.g-collections.com
# 33
# http://www.hentai-games.com/
# 34
# http://www.canadahentai.com
# 35
# http://www.hirameki-int.com
# 36
# http://www.himeyashop.com/
# 37
# http://www.jlist.com/
# 38
# http://www.clubspooey.com/spooey/
# 39
# http://www.hentaigamer.com
# 40
# http://www.pcrdist.com
# 41
# http://www.densetsu.com/
# 42
# http://www.animetric.com/bgames.html
# 43
# http://www.jmate.com/home.html
# 44
# http://www.three-musketeers.net/mike/animeopinions.html
# 45
# http://engbishoujo.tripod.com
# 46
# http://www.somethingawful.com/hentai/
# 47
# http://www.geocities.com/aetus_kane/reviews.html
# 48
# http://www.hentaigameszone.com
# 49
# http://www.hentaineko.com/html_peekv/peek_vgames.shtml
# 50
# http://www.asahi-net.or.jp/~uz9y-ab/yaoicomic.htm
# 51
# http://www.geocities.com/tokyo/villa/9953/yaoimain.html
# 52
# http://www.commonastherain.com/eros.html
# 53
# http://www.angelfire.com/anime3/hoshinokaze/
# 54
# http://www.discarnate.com/boysnextdoor/
# 55
# http://www.geocities.com/spirestudio/index.htm
# 56
# http://www.angelfire.com/me3/mandaplay/index.html
# 57
# http://www.geocities.com/tokyo/courtyard/9155/carosmen.htm
# 58
# http://members.tripod.com/~cheekokr/enter.html
# 59
# http://www.aoihayashi.com/
# 60
# http://www.geocities.com/shinji_is_my_man/
# 61
# http://www.cruelangel.net/divinitas/
# 62
# http://death_of_ase.tripod.com/dt/twisteddesire.html
# 63
# http://www.orchidveil.net/trapdoor/
# 64
# http://www.geocities.com/roryheadmav/main.html
# 65
# http://www.angelfire.com/anime4/wildefyre/
# 66
# http://www.yaoiluvr.net
# 67
# http://www.angelfire.com/goth2/azrael/
# 68
# http://m.webring.com/hub?ring=yaoi28
# 69
# http://onami.free.fr/
# 70
# http://www.geocities.com/obsidianblaze/
# 71
# http://p080.ezboard.com/badragonballyaoirpg
# 72
# http://www.pureyaoi.org/
# 73
# http://www.gaytoon-japan.com
# 74
# http://www.clubclassic.net/yaoi.html
# 75
# http://www.geocities.com/apple_toh/index.html
# 76
# http://www.gongaga.com/
# 77
# http://www.angelfire.com/goth/doujinshi_rapture/
# 78
# http://geocities.com/plugplaymanga/
# 79
# http://www.kinu-sekigushi.com/
# 80
# http://www.geocities.com/can_it_be_sin/index_2.html
# 81
# http://community.livejournal.com/jrockyaoi/
# 82
# http://arachnoid.reverie-noire.com/
# 83
# http://totchi.tripod.com/
# 84
# http://home.arcor.de/jrock-yaoi/index2.htm
# 85
# http://www.dtwins.co.uk/jfic/efiction30/index.php
# 86
# http://members.tripod.com/starchan/
# 87
# http://www.geocities.com/hushie_hush/
# 88
# http://www.cursedmoons.com/
# 89
# http://www.worldshaking.net/
# 90
# http://www.shoujoai.com/
# 91
# http://www.angelfire.com/anime2/yurifics/index.html
# 92
# http://groups.yahoo.com/group/lilypetalsandfallendewdrops/
# 93
# http://www.privateholes.com/anime/anime-sex/index6.html
# 94
# http://www.privateholes.com/anime/anime-asia/index6.html
# 95
# http://www.anime-hentai-cartoons.com/
# 96
# http://idd00788.eresmas.net/
# 97
# http://www.applicot.com/
# 98
# http://adultcompass.com/avs/0/1/acw/index.html
# 99
# http://www.adult-anime-hentai.com/
# 100
# http://www.emuck.com:3000/archive/egan.html
# 101
# http://danoday.com/summit.shtml
# 102
# http://groups.yahoo.com/group/voice_actor_appreciation/links/events_and_appearanc_000985383761/
# 103
# http://voice-international.com/
# 104
# http://www.livinglegendsltd.com/
# 105
# http://voicechasers.com/forum/viewforum.php?f=8
# 106
# http://hollywoodcollectorshow.com/
# 107
# http://www.geocities.com/hollywood/hills/8944/
# 108
# http://asifa.proboards61.com/index.cgi?action=calendarviewall
# 109
# http://groups.yahoo.com/group/voice_actor_appreciation/cal///group/voice_actor_appreciation/?v=42&amp;pos=
# 110
# http://us.imdb.com/name/nm0267724/
# 111
# http://www.pamelynferdin.com/
# 112
# http://www.pamferdin.com/
# 113
# http://www.monkeydog.com/
# 114
# http://teamknightrider.com/cast/plato/plato.html
# 115
# http://us.imdb.com/name/nm0281486/
# 116
# http://anp.awn.com/anifest-3.html
# 117
# http://www.awn.com/mag/issue1.7/articles/kowlaskidi1.7.html
# 118
# http://www.awn.com/mag/issue2.7/2.7pages/2.7jacksonjones.html
# 119
# http://www.awn.com/mag/issue1.9/articles/kowlagrinch1.9.html
# 120
# http://us.imdb.com/name/nm0004931/
# 121
# http://www.voicechasers.com/database/showactor.php?actorid=1251
# 122
# http://www.vortex.com/av.html#jayward1
# 123
# http://starbulletin.com/96/07/11/features/story3.html
# 124
# http://anp.awn.com/juneforay.html
# 125
# http://www.cerias.purdue.edu/homes/spaf/yucks/v2/msg00061.html
# 126
# http://www.awn.com/mag/issue5.03/5.03pages/evanierforay.php3
# 127
# http://www.awn.com/mag/issue4.02/4.02pages/foraylittlejohn.php3
# 128
# http://archives.seattletimes.nwsource.com/cgi-bin/texis.cgi/web/vortex/display?slug=voic29&amp;date=20000629
# 129
# http://www.geocities.com/enchantedforest/dell/8545/fraley.html
# 130
# http://us.imdb.com/name/nm0289710/
# 131
# http://www.voicechasers.com/database/showactor.php?actorid=1133
# 132
# http://patfraley.com/
# 133
# http://nerf-herders-anonymous.net/patfraley.html
# 134
# http://www.vasta.org/professional_index/fraleyp.html
# 135
# http://news.toonzone.net/2000/oct/27/hearing_voices.php#pat_on_the_head
# 136
# http://members.tripod.com/~leemichaelwithers/sfh.htm
# 137
# http://www.radiospirits.com/onradio/meethost_sf.asp
# 138
# http://us.imdb.com/name/nm0292677/
# 139
# http://freberg.westnet.com/
# 140
# http://www.aarp.org/mmaturity/mar_apr00_preview/creators.html#freberg
# 141
# http://www.cosmik.com/aa-october99/stan_freberg.html
# 142
# http://www.tsimon.com/freberg.htm
# 143
# http://www.firezine.net/issue6/fz6_07.htm
# 144
# http://www.thehutch.com/rabhutch/freberg.htm
# 145
# http://www.povonline.com/cols/col051.htm
# 146
# http://www.povonline.com/2001/news060901.htm
# 147
# http://www.austinchronicle.com/issues/dispatch/1999-12-10/music_feature3.html
# 148
# http://www.dawsbutler.com/freberg.htm
# 149
# http://freberg.westnet.com/list.html
# 150
# http://www.rhino.com/features/75645p.html
# 151
# http://hitcomedy.com/index.html?/act/freberg/
# 152
# http://www.cyberonic.net/~atrain/comedy/freberg.htm
# 153
# http://www.povonline.com/cols/col102.htm
# 154
# http://freberg.westnet.com/hear_it.html
# 155
# http://www.epinions.com/musc-album-musc-freberg__stan/tk_~mm032.1.2
# 156
# http://citypaper.net/articles/091699/mus.stan.shtml
# 157
# http://www.crispinfreeman.com/
# 158
# http://www.reelradio.com/gifts/frees.html
# 159
# http://www.spookytoms.com/paul_frees_tribute.html
# 160
# http://www.hollowhill.com/gm/library/frees.htm
# 161
# http://www.dvdtalk.com/dvdsavant/s74frees.html
# 162
# http://us.imdb.com/name/nm0293659/
# 163
# http://www.voicechasers.com/database/showactor.php?actorid=1248
# 164
# http://bakerstreetdozen.com/frewernews.html
# 165
# http://us.imdb.com/name/nm0001242/
# 166
# http://www.geocities.com/enchantedforest/dell/8545/va.html
# 167
# http://www.angelfire.com/ut/rtoons/actors.html
# 168
# http://www.geocities.com/hollywood/lot/2636/voiceacting/
# 169
# http://www.geocities.com/philbass_2000/narrators.html
# 170
# http://doreen.mkbmemorial.com/
# 171
# http://www.geocities.com/televisioncity/taping/6785/index.html
# 172
# http://www.behindthevoiceactors.com
# 173
# http://www.keyframeonline.com/kf.php?op=voic
# 174
# http://www.voicechasers.com/
# 175
# http://us.imdb.com/name/nm0304000/
# 176
# http://www.taoslandandfilm.com/bradentnwkly.html
# 177
# http://us.imdb.com/name/nm0004951/
# 178
# http://kathygarver.com/
# 179
# http://us.imdb.com/name/nm0308744/
# 180
# http://www.dickgautier.com/
# 181
# http://www.dangilvezan.com/
# 182
# http://us.imdb.com/name/nm0319737/
# 183
# http://us.imdb.com/name/nm0330015/
# 184
# http://www.tv-now.com/stars/gotfried.html
# 185
# http://www.cdaccess.com/html/pc/midmovie.htm
# 186
# http://genetic_mishap.tripod.com/landofthreenamedpeople/
# 187
# http://www.angelfire.com/celeb/starzbios/gottfried_g.html
# 188
# http://us.imdb.com/name/nm0331906/
# 189
# http://www-tech.mit.edu/v110/n37/gilber.37a.html
# 190
# http://www-tech.mit.edu/v110/n38/lsc.38a.html
# 191
# http://www.octopusmediaink.com/gilbertgottfried.html
# 192
# http://citypaper.net/articles/022996/article001.shtml
# 193
# http://jam.canoe.ca/movies/artists/g/gottfried_gilbert/1997/02/21/758674.html
# 194
# http://www.voicechasers.com/database/showactor.php?actorid=2148
# 195
# http://www.kylehebert.com/
# 196
# http://www.post-gazette.com/magazine/19990223voicetalent1.asp
# 197
# http://www.serkworks.com/roommates/index.htm
# 198
# http://www.armory.com/~keeper/jesshirt.html
# 199
# http://www.voicechasers.com/database/showactor.php?actorid=1220
# 200
# http://docharris.com/
# 201
# http://www.lushmedia.co.uk/
# 202
# http://www.dav-productions.com/
# 203
# http://www.ccvideo.net/
# 204
# http://www.blueyed.com/
# 205
# http://www.koalatv.com/
# 206
# http://www.goaggressive.com/
# 207
# http://www.emblemma.com/
# 208
# http://www.killingtimeproductions.com/
# 209
# http://www.rollingrproductions.com/
# 210
# http://www.boutwellstudios.com
# 211
# http://www.blindruckus.com
# 212
# http://www.roadrecords.com/clientlist.html
# 213
# http://www.coupestudios.com
# 214
# http://www.kellogg-rice.com
# 215
# http://www.sarley.com
# 216
# http://www.deadlyproductions.com
# 217
# http://www.rickaudio.com
# 218
# http://www.fmsystems.net
# 219
# http://www.gamebeatinc.com/
# 220
# http://members.tripod.com/kcepap/
# 221
# http://www.loftinpro.com
# 222
# http://www.noisefloor.com
# 223
# http://www.wavegroup.com
# 224
# http://www.audiolinks.com/
# 225
# http://business.fortunecity.com/tisch/809/gold.htm
# 226
# http://www.harkproductions.com/audio.html
# 227
# http://www.loree-nelson.com
# 228
# http://www.thilldesign.com
# 229
# http://www.cgdesign.com
# 230
# http://www.moonaluna.net
# 231
# http://www.rjbstudio.com
# 232
# http://www.folioinc.com
# 233
# http://www.colorpagesinc.com
# 234
# http://www.svengoody.com
# 235
# http://www.doclivingston.com
# 236
# http://www.broadsideinteractive.com/
# 237
# http://www.celticharper.com/wolfhawk.html
# 238
# http://www.copelandesign.com
# 239
# http://www.gilmourcreative.com
# 240
# http://www.twentyfirst.co.uk
# 241
# http://www.blacktide.com
# 242
# http://www.magusgraphics.com
# 243
# http://www.geocities.com/svendesign/
# 244
# http://www.graphicsillustrated.com
# 245
# http://sullivancreative.com
# 246
# http://www.thincgrafx.com/
# 247
# http://www.rappyco.com
# 248
# http://www.vcpresentations.com/
# 249
# http://www.philipperaimbault.com
# 250
# http://www.jandjgraphics.com
# 251
# http://www.transmediaproject.com/
# 252
# http://www.informationexperts.com/
# 253
# http://www.pluribusmedia.com/
# 254
# http://www.adaptivedesign.com
# 255
# http://www.logodesignonline.com
# 256
# http://www.pentagonstudios.com
# 257
# http://www.cre8tivproductions.com
# 258
# http://www.stevensonsharpe.co.uk
# 259
# http://millercreative.com
# 260
# http://www.e-nimation.com/
# 261
# http://www.springdesigngroup.com
# 262
# http://www.newsdesign.com.hk
# 263
# http://www.ronelmm.com
# 264
# http://www.themakers.com
# 265
# http://www.mochamedia.com
# 266
# http://www.maksimedia.com
# 267
# http://www.lughstudio.com
# 268
# http://www.osprey.com
# 269
# http://www.somme.no/
# 270
# http://www.impactgroup.com
# 271
# http://paulmaple.co.uk/media/
# 272
# http://www.pennvid.com
# 273
# http://www.cell-media.com/
# 274
# http://www.concisegroup.com/
# 275
# http://www.picturevideo.com
# 276
# http://www.accelvideo.com
# 277
# http://www.altana.com.ar
# 278
# http://www.allvid.com/
# 279
# http://www.babadigital.com
# 280
# http://www.mcdougalldigital.com
# 281
# http://www.imacron.com/
# 282
# http://www.reelized.com/
# 283
# http://www.vandongenav.nl
# 284
# http://www.rubiconproductions.com
# 285
# http://www.visionsoundcomm.com
# 286
# http://www.avrs.net/
# 287
# http://www.vldigital.com
# 288
# http://www.videomagicpro.net/
# 289
# http://www.swerdlow.co.uk/
# 290
# http://www.sierrabreeze.com
# 291
# http://www.jnproductions.com/
# 292
# http://www.scribblemedia.com
# 293
# http://www.stormshooters.com
# 294
# http://www.bigshoulders.com
# 295
# http://www.1digital.com
# 296
# http://www.manningproductions.com
# 297
# http://www.videocopies.com
# 298
# http://www.cardinal-broadcast.com
# 299
# http://www.dvfilm.com
# 300
# http://www.parrottastudio.com
# 301
# http://www.pearlmanaudiovideo.com
# 302
# http://www.pagerankers.com
# 303
# http://www.purevisibility.com
# 304
# http://www.pepperjam.com/
# 305
# http://www.platinumservices.com
# 306
# http://powerspiritonline.com
# 307
# http://www.project36.com
# 308
# http://www.pageviews.com/
# 309
# http://www.podiums.co.uk/
# 310
# http://www.portlandwebvisibility.com
# 311
# http://www.pagearnold.co.uk/
# 312
# http://www.quadrapromotions.com/
# 313
# http://www.qxest.net/
# 314
# http://www.quisma.de/
# 315
# http://www.quirk.biz/
# 316
# http://www.top-website-promotion.co.uk/
# 317
# http://www.redcarpetweb.com/
# 318
# http://www.rocketlist.com/
# 319
# http://www.registersuccess.com/
# 320
# http://www.raise-your-sites.co.uk/
# 321
# http://www.reinventbusiness.com/
# 322
# http://www.rainstormconsulting.com/
# 323
# http://www.resortwebmarketing.com/
# 324
# http://www.rbimedia.com/
# 325
# http://www.receptional.com/
# 326
# http://www.rankhigh.net/
# 327
# http://www.redzoneglobal.net/
# 328
# http://www.raisemyrank.com/
# 329
# http://www.registereverywhere.com/
# 330
# http://www.rankingman.com/
# 331
# http://www.rankforsales.com/
# 332
# http://www.econnects.net/
# 333
# http://www.rankmagic.com/
# 334
# http://www.relevanttraffic.com/
# 335
# http://www.ranks.nl/consultancy/
# 336
# http://www.ranbury.com/
# 337
# http://www.rugles.com/
# 338
# http://www.redlineseo.com/
# 339
# http://www.refreshweb.com/
# 340
# http://www.rstwebsolutions.com/
# 341
# http://www.reidtechnologies.ca/
# 342
# http://www.rtproservices.com/
# 343
# http://www.room214.com/
# 344
# http://www.seo-websitepromotion.com/
# 345
# http://www.rankuno.com/
# 346
# http://www.roadmap-placement.com/
# 347
# http://www.rimmkaufman.com/
# 348
# http://www.rossjackson.co.uk/
# 349
# http://www.raspberrymarketing.com/
# 350
# http://www.resolutionmedia.com
# 351
# http://www.ranksubmit.com/
# 352
# http://www.rankhigh.biz/
# 353
# http://www.top-search-engine-ranking.co.uk/
# 354
# http://www.rapidblue.co.uk/
# 355
# http://www.ringjohn.com/
# 356
# http://riseinteractive.com/
# 357
# http://www.relaxseo.com
# 358
# http://www.redchillimarketing.co.uk
# 359
# http://www.reseo.com
# 360
# http://www.internetcampaignmanagement.com
# 361
# http://www.rootconcepts.com
# 362
# http://www.redchillisearch.com
# 363
# http://www.rankfirst.com.au
# 364
# http://www.realonlinemarketing.com
# 365
# http://www.revteq.com
# 366
# http://www.group41.com/
# 367
# http://www.sagerock.com/
# 368
# http://www.seotechnologies.com
# 369
# http://www.submit-url.net/
# 370
# http://www.searchengineer.co.uk/
# 371
# http://www.submission-pro.com/
# 372
# http://www.searchenginedesign.com/
# 373
# http://www.submit-pro.com/
# 374
# http://www.sixtop.co.uk/
# 375
# http://www.spiderbait.com/
# 376
# http://www.searchintelligence.ca/
# 377
# http://www.singlethrow.com/
# 378
# http://www.sitelynx.com/
# 379
# http://www.searchengineserious.co.uk/
# 380
# http://www.submitnet.net/
# 381
# http://www.searchsummit.com/
# 382
# http://www.searchenginewiz.com/
# 383
# http://www.slickwebz.com/
# 384
# http://www.searchenginetechnologies.com/
# 385
# http://www.seoanalysis.com/
# 386
# http://www.stepforth.com
# 387
# http://www.searchenginepatrol.com/
# 388
# http://www.searchanalysts.com/
# 389
# http://www.sitesolutions.com/
# 390
# http://www.stickyeyes.com/
# 391
# http://www.skipechert.com/
# 392
# http://www.sitepropel.com/
# 393
# http://www.searchenginepeople.com/
# 394
# http://www.submit-away.com/
# 395
# http://www.submitawebsite.com/
# 396
# http://www.superwebsitepromotion.com/
# 397
# http://www.successpromotions.com/
# 398
# http://www.siteblaster.co.uk/
# 399
# http://www.searchinnovation.com/
# 400
# http://www.submittoday.com/
# 401
# http://www.searchmar.com/
# 402
# http://www.seoinc.com/
# 403
# http://www.foryoursoft.com/hypercalendar/
# 404
# http://www.mdesoft.com/home_eng.htm
# 405
# http://contactplus.com/products/freestuff/task.htm
# 406
# http://www.cotton100.com/
# 407
# http://www.inklineglobal.org/products/vdp/
# 408
# http://www.sharewaresolutions.com/html/calendar.html
# 409
# http://www.amfsoftware.com/windows/amfpim.html
# 410
# http://www.idealcs.com/calendar/
# 411
# http://www.zabaware.com/assistant/index.html
# 412
# http://compunac.homestead.com/index.html
# 413
# http://www.calendarmine.com/
# 414
# http://www.hammersoftware.com/calendar.html
# 415
# http://www.calendarscope.com/
# 416
# http://www.zb2000.com/acecalendar.htm
# 417
# http://www.daansystems.com/daancalendar/
# 418
# http://hotshift.tripod.com/
# 419
# http://www.twesley.com/~shiftcal/
# 420
# http://www.naturcalendar.com/
# 421
# http://www.calnique.com/
# 422
# http://www.wallpaper-calendar.com/
# 423
# http://www.vaxtech.com/birthday-reminder.htm
# 424
# http://www.srosoftware.com/sro_bc.htm
# 425
# http://www.cm-soft.net/index1.html
# 426
# http://www.ecrew.org/
# 427
# http://www.softshape.com/cham/
# 428
# http://www.dummysoftware.com/clockdummy.html
# 429
# http://www.cheqsoft.com/timesown.html
# 430
# http://www.uk-software.com/speakingclock.htm
# 431
# http://www.dillobits.com/
# 432
# http://www.altrixsoft.com
# 433
# http://ourworld.compuserve.com/homepages/anithmi/cyclocke.htm
# 434
# http://www.atomtime.com/
# 435
# http://www.mtnsys.com/pages/atomicclock.htm
# 436
# http://www.paraben.com/html/clock2.html
# 437
# http://www.kaska.demon.co.uk/
# 438
# http://www.nestersoft.com/timeleft/
# 439
# http://www.chemware.co.nz/tic.htm
# 440
# http://www.blueprintsoftwareworks.com/atomsync/
# 441
# http://www.hoursandminutes.com/
# 442
# http://www.hiclock.com/
# 443
# http://www.springcreeksoftware.com/
# 444
# http://timerecorder.51.net/
# 445
# http://www.rayslab.com/atomic_clock/atomic_clock.html
# 446
# http://www.info-pack.com/datetray/
# 447
# http://www.lux-aeterna.com/clock/
# 448
# http://www.enins.com/timesled/
# 449
# http://www.acutesoftware.com.au/timer.html
# 450
# http://www.timeutilites.com/
# 451
# http://www.nehuenmultimedia.com.ar/html/atomic_clock.html
# 452
# http://www.softdemon.com/clock/
# 453
# http://www.timezonesforpcs.com/
# 454
# http://www.xnotestopwatch.com/
# 455
# http://visualversion.com/timebuddy/index.html
# 456
# http://www.rpoint.com/pp/alarm-pro.aspx
# 457
# http://www.lmhsoft.com/timesync/
# 458
# http://www.vioio.com/mp3alarmclock.htm
# 459
# http://littlemulticlock.com/littlemulticlock/files/littlemulticlock.html
# 460
# http://www.shelltoys.com/speaking_clock/
# 461
# http://www.basta.com/prodhoras.htm
# 462
# http://www.elprime.com/
# 463
# http://www.atsync.com/
# 464
# http://www.12noon.com/
# 465
# http://www.talkingtimekeeper.com/
# 466
# http://www.thecountdownclock.com/
# 467
# http://www.softros-tools.com/
# 468
# http://www.saythetime.com/
# 469
# http://www.utech.net.au/index.php?option=com_content&amp;task=category&amp;sectionid=1&amp;id=1&amp;itemid=50
# 470
# http://www.loginor.qc.ca/index_e.html
# 471
# http://www.azzcardfile.com/
# 472
# http://www.mxac.com.au/dragonfly.htm
# 473
# http://www.tgslabs.com/
# 474
# http://www.gammadyne.com/sb.htm
# 475
# http://www.encodeteam.com/
# 476
# http://www.msdsoft.com/agenda/eng/index.htm
# 477
# http://www.inklineglobal.org/
# 478
# http://www.neverforget.com/
# 479
# http://www.cyber-matrix.com/prosched.html
# 480
# http://www.1soft.com/aandb.html
# 481
# http://www.ezoutliner.com/
# 482
# http://www.xreminder.com/
# 483
# http://www.inklineglobal.com/products/vdp/
# 484
# http://www.wjjsoft.com/
# 485
# http://www.personalmicrocosms.com/html/32bit.html
# 486
# http://www.pollensoftware.com/task-o-matic/
# 487
# http://www.angelfire.com/ia/anniversary/
# 488
# http://www.bitsmithsoft.com/
# 489
# http://www.mynotescenter.com/
# 490
# http://www.csoftlab.com/
# 491
# http://www.cancellieri.org/pmo_index.htm
# 492
# http://softnote.com/
# 493
# http://www.denverresearch.com/pim/home.shtml
# 494
# http://www.jsoftconsulting.com/
# 495
# http://www.cancellieri.org/
# 496
# http://www.winpim.com/
# 497
# http://www.lexasoftware.com
# 498
# http://www.cancellieri.org/apim_index.htm
# 499
# http://www.freedomsoftware.net/
# 500
# http://www.joels-journal.com/
# 501
# http://www.pimone.com/
# 502
# http://www.angelicsoftware.com/
# 503
# http://www.freedomsoftware.net/notebook.html
# 504
# http://www.geocities.com/angelicangelsnf/
# 505
# http://www.arenel.com
# 506
# http://home.insightbb.com/~bastshaman/index.html
# 507
# http://www.becks-cats.com
# 508
# http://www.bedoroses.com/
# 509
# http://www.angelfire.com/ms/brikalacy/
# 510
# http://castleglen.homestead.com/intro.html
# 511
# http://catnipkids.homestead.com/cattery.html
# 512
# http://www.cayugafarm.com
# 513
# http://www.geocities.com/demiaracats/cattery.html
# 514
# http://www.geocities.com/himalayancats2000/index.html
# 515
# http://everdreamhimalayan.tripod.com/
# 516
# http://www.fancyfriends.com/
# 517
# http://www.fancyfluff.i8.com
# 518
# http://www.geocities.com/fluffydreamscatteryca/index.html
# 519
# http://www.furpleasure.com/
# 520
# http://godzanointed4him.homestead.com/
# 521
# http://www.geocities.com/himicats/
# 522
# http://www.itikat.com/
# 523
# http://www.kattenbach.com
# 524
# http://www.kutzikoo.com
# 525
# http://www.geocities.com/labonita_persians/
# 526
# http://www.leclubfur.com/
# 527
# http://www.geocities.com/luvhavencats/
# 528
# http://sulebrity.homestead.com/
# 529
# http://www.geocities.com/sunnylakes/
# 530
# http://www.tanglebox.net
# 531
# http://home19.inet.tele.dk/teahs/
# 532
# http://www.tinyjewels.homestead.com/index.html
# 533
# http://www.tntpuff.com
# 534
# http://www.whisperwoodcats.com/
# 535
# http://www.yewcats.com/
# 536
# http://www.geocities.com/milhorn2002/index.html
# 537
# http://www.pawsandpurrscattery.com/
# 538
# http://www.fancyfurs.net
# 539
# http://www.naru.20m.com
# 540
# http://home.earthlink.net/~sandypaws/
# 541
# http://playwickeycats.com/index.shtml#top
# 542
# http://www.ristokat.com/
# 543
# http://www.catteryrow.com/pacificpurr/index.html
# 544
# http://www.geocities.com/paisleypaws/
# 545
# http://radzacatz.homestead.com/
# 546
# http://www.members.tripod.com/izshe/
# 547
# http://www.pawtrixcove.com
# 548
# http://www.sunstreamcats.com/
# 549
# http://www.ceylon.ws
# 550
# http://www.himmikatz.com/
# 551
# http://www.geocities.com/fuzzy_britches1/fuzzybritches.html
# 552
# http://www.kasiakatz.com
# 553
# http://katzcaprice.com
# 554
# http://www.ma-liakatz.com/
# 555
# http://www.blackriverhimalayans.20m.com
# 556
# http://www.ieasysite.com/sunshinezzz
# 557
# http://www.catleycrue.com
# 558
# http://www.pointedpurrs.com/
# 559
# http://www.nymews.com
# 560
# http://www.geocities.com/kitties2luv/
# 561
# http://www.geocities.com/angelpawscattery2003/index.html
# 562
# http://www.geocities.com/sunnybrookkittens/
# 563
# http://www.shadenshadow.com
# 564
# http://www.furrmine.com
# 565
# http://www.silkenrosepersians.com
# 566
# http://www.kaydekatz.com
# 567
# http://www.geocities.com/heavenlymews/
# 568
# http://jentopiacats.com
# 569
# http://www.purrs-of-luvcattery.com
# 570
# http://www.purfectkittypersians.com/
# 571
# http://www.geocities.com/maxnkoko/index.html
# 572
# http://www.grovewoodcats.com/
# 573
# http://www.lechatpaws.com/
# 574
# http://kisancats.com/
# 575
# http://www.lakehyco.com/
# 576
# http://webpages.charter.net/sassipurrs/
# 577
# http://www.co-bridge.com
# 578
# http://www.calebcats.com
# 579
# http://rumscott.homestead.com/
# 580
# http://www.wonderfluf.com
# 581
# http://sunshinezzz.ieasysite.com/
# 582
# http://www.ozemail.com.au/~ebunny
# 583
# http://planeta.terra.com.br/lazer/gatilmiragem
# 584
# http://www.blazestar.com.br/
# 585
# http://www.himalayan.org/
# 586
# http://www.geocities.com/area51/dreamworld/9882/index.html
# 587
# http://www.cfainc.org/breeds/profiles/persian-him.html
# 588
# http://www.aaceinc.org/pages/breeds/him.htm
# 589
# http://p.webring.com/hub?ring=himi
# 590
# http://www.cfainc.org/breeds/profiles/japanese.html
# 591
# http://www.breedlist.com/japanese-bobtail-breeders.html
# 592
# http://www.japanesebobtails.com/
# 593
# http://www.cfainc.org/breeds/profiles/articles/japanese.html
# 594
# http://www.fanciers.com/breed-faqs/japanese-bobtail-faq.html
# 595
# http://www.catchicats.com/
# 596
# http://www.kiddlyn.com/
# 597
# http://www.angelfire.com/il3/jakoi/
# 598
# http://www.sailbourne.com/
# 599
# http://www.janipurr.com/
# 600
# http://www.geocities.com/kurisumasu_jbt/
# 601
# http://members.shaw.ca/jbobtails/index.htm
# 602
# http://www.solstans.co.uk/
# 603
# http://www.goutokuji.com/
# 604
# http://www.samizcats.com
# 605
# http://www.uvm.edu/~video/
# 606
# http://learn.uvm.edu/focus/
# 607
# http://www.uvm.edu/~gradcoll/
# 608
# http://www.uvm.edu/academics/?page=grad.html&amp;sm=gm.html
# 609
# http://www.uvm.edu/~histpres
# 610
# http://www.uvm.edu/~biomed/
# 611
# http://www.uvm.edu/~cnhs/
# 612
# http://www.bsad.uvm.edu/
# 613
# http://www.uvm.edu/~envprog/
# 614
# http://www.uvm.edu/snr/
# 615
# http://www.uvm.edu/snr/?page=master_phd_info/snr_doctor.html
# 616
# http://www.uvm.edu/snr/?page=undergrads/enviro_sciences.html
# 617
# http://www.uvm.edu/snr/?page=undergrads/forestry.html
# 618
# http://www.uvm.edu/snr/?page=undergrads/natural_res.html
# 619
# http://www.uvm.edu/snr/?page=undergrads/rec_management.html
# 620
# http://www.uvm.edu/snr/?page=undergrads/wlfbio.html
# 621
# http://www.uvm.edu/~dceweb/lane/
# 622
# http://www.uvm.edu/~sacon/
# 623
# http://www.uvm.edu/~ncow/
# 624
# http://www.uvm.edu/events/
# 625
# http://www.uvm.edu/~uvmcts/
# 626
# http://www.uvm.edu/~fleming/index.php?category=events&amp;page=events
# 627
# http://www.uvm.edu/~jdavison/
# 628
# http://www.uvm.edu/~sjc/
# 629
# http://www.emba.uvm.edu/~archdeac/
# 630
# http://www.uvm.edu/~jleonard/
# 631
# http://www.emba.uvm.edu/~read/
# 632
# http://www.uvm.edu/~rullrich/first.html
# 633
# http://www.emba.uvm.edu/~mirchand/
# 634
# http://mansfield.emba.uvm.edu/~douglas/
# 635
# http://www.emba.uvm.edu/~rcrouse/
# 636
# http://www.uvm.edu/~dbarring/home.html
# 637
# http://www.emba.uvm.edu/~dinitz/
# 638
# http://www.emba.uvm.edu/~dben/
# 639
# http://www.emba.uvm.edu/~burgmeie/
# 640
# http://www.emba.uvm.edu/~cooke/
# 641
# http://www.emba.uvm.edu/~puterbau/
# 642
# http://www.emba.uvm.edu/~wilson/
# 643
# http://www.uvm.edu/~dguber/
# 644
# http://www.emba.uvm.edu/~snapp/
# 645
# http://www.uvm.edu/~hag/personal/
# 646
# http://www.uvm.edu/~lizzo/
# 647
# http://www.uvm.edu/~der/
# 648
# http://www.uvm.edu/~jdion/
# 649
# http://www.uvm.edu/~dmatthew/
# 650
# http://www.uvm.edu/academics/catalogue2006-07/
# 651
# http://optimization.asu.edu/~xue/
# 652
# http://universitycommunications.uvm.edu/spring2001/webreleaseonunionpetitionresponse.htm
# 653
# http://www.unitedacademics.org/
# 654
# http://voyager.uvm.edu/
# 655
# http://www.uvm.edu/whale/
# 656
# http://www.uvm.edu/~fleming/
# 657
# http://library.uvm.edu/
# 658
# http://library.uvm.edu/dana/
# 659
# http://www.uvm.edu/perkins/
# 660
# http://www.uvm.edu/~pmrc/pmrccam.html
# 661
# http://universitycommunications.uvm.edu/tour/?page=buildings
# 662
# http://www.uvm.edu/~pmrc/sugarcam.html
# 663
# http://www.uvm.edu/map/
# 664
# http://www.uvm.edu/about_uvm/visiting/?page=greencam.html
# 665
# http://www.uvm.edu/uvmtoday/
# 666
# http://universitycommunications.uvm.edu/vq/index.html
# 667
# http://universitycommunications.uvm.edu/
# 668
# http://www.vermontcynic.com/
# 669
# http://www.uvm.edu/~vtconn/
# 670
# http://www.uvm.edu/~uvmemu/
# 671
# http://www.uvm.edu/~uvmtv/
# 672
# http://www.uvm.edu/~wruv/
# 673
# http://www.uvm.edu/~aaeo/
# 674
# http://giraffe.uvm.edu/~rgweb/
# 675
# http://reslife.uvm.edu/
# 676
# http://www.uvm.edu/~energy/
# 677
# http://www.uvm.edu/~uvmppd/
# 678
# http://www.uvm.edu/~cntrllrs/
# 679
# http://www.uvm.edu/~ofabweb/
# 680
# http://www.uvm.edu/~ugpdept/
# 681
# http://www.uvm.edu/~photo/
# 682
# http://www.uvm.edu/~catcard/
# 683
# http://www.uvm.edu/~plan/
# 684
# http://www.uvm.edu/~afsdept/
# 685
# http://www.uvm.edu/~uvmhr/
# 686
# http://www.uvm.edu/~training/
# 687
# http://www.uvm.edu/~sisi/
# 688
# http://www.uvm.edu/~purcard/
# 689
# http://www.uvm.edu/~arch/
# 690
# http://www.uvm.edu/~uvmppd/?page=services/surplus/default.html&amp;mm=blankmenu.html
# 691
# http://www.uvm.edu/~ospuvm/
# 692
# http://www.uvm.edu/~oacm/
# 693
# http://www.uvm.edu/studentlife/
# 694
# http://www.uvm.edu/~clascomp/
# 695
# http://www.uvm.edu/~dos/assist/
# 696
# http://www.uvm.edu/~juggle/
# 697
# http://www.uvm.edu/~uvmopt/
# 698
# http://debate.uvm.edu/
# 699
# http://www.uvm.edu/~service/
# 700
# http://www.uvm.edu/~catfs/
# 701
# http://www.uvm.edu/~alco/
# 702
# http://www.uvm.edu/sparc/
# 703
# http://www.uvm.edu/~uvmwoc/
# 704
# http://www.uvm.edu/~outside/
# 705
# http://www.uvm.edu/~topcats/
# 706
# http://www.uvm.edu/~legal
# 707
# http://www.uvm.edu/~rescue/
# 708
# http://www.uvm.edu/~hearts/
# 709
# http://www.uvm.edu/~boulder/
# 710
# http://www.uvm.edu/~skiclub/
# 711
# http://www.uvm.edu/greening/
# 712
# http://www.uvm.edu/~uvmsga/
# 713
# http://www.uvm.edu/~rlweb/ira/
# 714
# http://www.emba.uvm.edu/~asem
# 715
# http://www.emba.uvm.edu/~asce/
# 716
# http://www.emba.uvm.edu/~asme/
# 717
# http://www.emba.uvm.edu/~cssa/
# 718
# http://www.uvm.edu/~geogclub/
# 719
# http://www.uvm.edu/~goodrich/
# 720
# http://pss.uvm.edu/hortclub/
# 721
# http://www.uvm.edu/~phibeta/
# 722
# http://universitycommunications.uvm.edu/fall99releases/webclimbthewalls.htm
# 723
# http://www.uvmgreeklife.com/
# 724
# http://www.agrinvt.org/
# 725
# http://www.uvm.edu/~fiji2
# 726
# http://www.uvm.edu/~sigep/
# 727
# http://www.uvm.edu/~aphio/
# 728
# http://www.uvm.edu/~sigmaphi/home.htm
# 729
# http://www.uvm.edu/~uvmaz/
# 730
# http://uvm.phideltatheta.org/
# 731
# http://www.uvm.edu/~tridelt/
# 732
# http://www.uvm.edu/~uvmivcf/
# 733
# http://www.uvmhillel.org/
# 734
# http://www.uvm.edu/~ohpr/
# 735
# http://www.uvm.edu/~helix/
# 736
# http://www.uvm.edu/~vlrs/
# 737
# http://pss.uvm.edu/dept/hort_farm/
# 738
# http://www.uvm.edu/~crvt/
# 739
# http://crs.uvm.edu/
# 740
# http://www.uvm.edu/~susagctr/
# 741
# http://www.uvm.edu/~uvmsbf/
# 742
# http://www.uvm.edu/~dmatthew/
# 743
# http://orchard.uvm.edu/
# 744
# http://blood.uvm.edu/
# 745
# http://www.uvm.edu/~uvmchs/
# 746
# http://www.uvm.edu/~vtreads/uvmhome.html
# 747
# http://www.snellingcenter.org/
# 748
# http://www.uvm.edu/~epscor/
# 749
# http://www.uvm.edu/~plantbio/?page=research.html&amp;sm=researchmenu.html
# 750
# http://www.uvm.edu/vtaes/
# 751
# http://www.uvm.edu/~cdci/
# 752
# http://cwf.uvm.edu/cris/
# 753
# http://www.uvminnovations.com/
# 754
# http://www.rcgrd.uvm.edu/
# 755
# http://www.dad.state.vt.us/atp/resource%20links/communication.htm
# 756
# http://www.uvm.edu/envnr/vtcfwru/
# 757
# http://www.uvm.edu/~envnr/sal/
# 758
# http://www.uvm.edu/~compor/
# 759
# http://www.uvm.edu/~pmrc/
# 760
# http://vtspacegrant.org/
# 761
# http://www.uvm.edu/uvmtoday/community.html
# 762
# http://www.uvm.edu/~dpelkey/
# 763
# http://agave.garden.org/~aaronh/
# 764
# http://www.uvm.edu/~learnco/
# 765
# http://www.uvm.edu/~police/
# 766
# http://www.uvm.edu/~spirit/
# 767
# http://www.uvm.edu/~counscen/
# 768
# http://www.uvm.edu/~oies/
# 769
# http://www.uvm.edu/~women/
# 770
# http://www.uvm.edu/~ccpuvm/
# 771
# http://www.uvm.edu/~lgbtqa/
# 772
# http://ctl.uvm.edu/
# 773
# http://www.uvm.edu/health/
# 774
# http://www.uvm.edu/~tpswww/
# 775
# http://uds.uvm.edu/
# 776
# http://www.uvm.edu/~access/
# 777
# http://www.uvm.edu/~uvmiac/
# 778
# http://www.uvm.edu/~career
# 779
# http://siri.uvm.edu/
# 780
# http://esf.uvm.edu/
# 781
# http://www.uvm.edu/~wrtngctr/
# 782
# http://www.vermontlaw.edu/
# 783
# http://www.vjel.org
# 784
# http://www.woodbury-college.edu/
# 785
# http://www.gwvirginia.gwu.edu/
# 786
# http://www.cdu.edu/
# 787
# http://www.umtweb.edu/
# 788
# http://www.virginia529.com/
# 789
# http://www.uacp.org
# 790
# http://www.cordobauniversity.org/
# 791
# http://www.artinstitutes.edu/arlington/
# 792
# http://www.apprenticeschool.com
# 793
# http://www.gobuilders.com/
# 794
# http://www.abbc.edu/
# 795
# http://www.averett.edu/
# 796
# http://www.averettcougars.com/
# 797
# http://www.bluefield.edu/
# 798
# http://www.bluefield.edu/templates/system/details.asp?id=30250&amp;pid=250316
# 799
# http://www.bridgewater.edu/
# 800
# http://www.bridgewater.edu/athletics
# 801
# http://christ-college.com/
# 802
# http://www.christendom.edu
# 803
# http://www.christendom.edu/athletics/
# 804
# http://www.cnu.edu/
# 805
# http://www.cnubooks.com/
# 806
# http://eebweb.arizona.edu/faculty/hopp/vireo.html
# 807
# http://www.utahbirds.org/birdsofutah/birdsl-r/plumbeousvireo.htm
# 808
# http://www.greglasley.net/gvireo.html
# 809
# http://birds.cornell.edu/bfl/speciesaccts/casvir.html
# 810
# http://www.mbr-pwrc.usgs.gov/id/framlst/i6230id.html
# 811
# http://www.wbu.com/chipperwoods/photos/revireo.htm
# 812
# http://www.stanfordalumni.org/birdsite/text/species/hutton's_vireo.html
# 813
# http://www.mbr-pwrc.usgs.gov/id/framlst/i6290id.html
# 814
# http://faculty.ncwc.edu/mbrooks/pif/bird%20profiles/whiteeyed_vireo.htm
# 815
# http://www.arthurgrosset.com/sabirds/rufous-browed%20peppershrike.html
# 816
# http://www.arthurgrosset.com/sabirds/slaty-cappedshrike-vireo.html
# 817
# http://audubon2.org/webapp/watchlist/viewspecies.jsp?id=31
# 818
# http://www.mbr-pwrc.usgs.gov/id/framlst/i6330id.html
# 819
# http://www.amonline.net.au/factsheets/silvereye.htm
# 820
# http://www.kenyabirds.org.uk/nhs_w_eye.htm
# 821
# http://www.birdlife.org/datazone/species/index.html?action=spchtmdetails.asp&amp;sid=7451&amp;m=0
# 822
# http://www.nzbirds.com/birds/tauhou.html
# 823
# http://en.wikipedia.org/wiki/estrildid_finch
# 824
# http://en.wikipedia.org/wiki/swee_waxbill
# 825
# http://astorwilliam.tripod.com/
# 826
# http://en.wikipedia.org/wiki/muscicapidae
# 827
# http://www.naturia.per.sg/buloh/birds/copsychus_saularis.htm
# 828
# http://www.birdguides.com/species/species.asp?sp=137055
# 829
# http://www.birdguides.com/species/species.asp?sp=137026
# 830
# http://www.birdguides.com/species/species.asp?sp=137063
# 831
# http://www.birdguides.com/species/species.asp?sp=137056
# 832
# http://ibc.hbw.com/ibc/phtml/familia.phtml?idfamilia=141
# 833
# http://en.wikipedia.org/wiki/pycnonotidae
# 834
# http://www.naturia.per.sg/buloh/birds/pycnonotus_goiavier.htm
# 835
# http://www.birdlife.org/datazone/species/index.html?action=spchtmdetails.asp&amp;sid=7299&amp;m=0
# 836
# http://www.birdlife.org/datazone/species/index.html?action=spchtmdetails.asp&amp;sid=7305&amp;m=0
# 837
# http://www.birdlife.org/datazone/species/index.html?action=spchtmdetails.asp&amp;sid=7304&amp;m=0
# 838
# http://en.wikipedia.org/wiki/cisticolidae
# 839
# http://www.naturia.per.sg/buloh/birds/prinia_flaviventris.htm
# 840
# http://en.wikipedia.org/wiki/nectarinidae
# 841
# http://www.naturia.per.sg/buloh/birds/nectarina_calcosthetha.htm
# 842
# http://www.naturia.per.sg/buloh/birds/nectarina_jugularis.htm
# 843
# http://home1.gte.net/dgl1/pelican.html
# 844
# http://raysweb.net/specialplaces/pages/pelican.html
# 845
# http://animaldiversity.ummz.umich.edu/site/accounts/information/pelecanus_erythrorhynchos.html
# 846
# http://animaldiversity.ummz.umich.edu/site/accounts/information/pelecanus_occidentalis.html
# 847
# http://www.kenyabirds.org.uk/gw_pelican.htm
# 848
# http://www.kenyabirds.org.uk/pb_pelican.htm
# 849
# http://migratorybirds.fws.gov/issues/cormorant/greatlakes_q&amp;a.htm
# 850
# http://web.tiscali.it/sv2001/
# 851
# http://nzbirds.com/birds/kawau.html
# 852
# http://www.coldwaterimages.com/brandt_s_cormorant.html
# 853
# http://www.kenyabirds.org.uk/great_cormorant.htm
# 854
# http://www.kenyabirds.org.uk/cormorant-lt.htm
# 855
# http://animaldiversity.ummz.umich.edu/site/accounts/information/sula_nebouxii.html
# 856
# http://bioweb.uwlax.edu/bio203/s2008/kops_aman/
# 857
# http://www.fws.gov/midway/mabo.html
# 858
# http://en.wikipedia.org/wiki/sula_(bird)
# 859
# http://www.fws.gov/midway/brbo.html
# 860
# http://www.fws.gov/midway/rfbo.html
# 861
# http://www.nzbirds.com/birds/takapu.html
# 862
# http://en.wikipedia.org/wiki/darter
# 863
# http://www.kenyabirds.org.uk/darter.htm
# 864
# http://ibc.hbw.com/ibc/phtml/familia.phtml?idfamilia=18
# 865
# http://www.thebigzoo.com/animals/lesser_flamingo.asp
# 866
# http://www.geocities.com/flamingo22701/flamingo_mania
# 867
# http://www.geocities.com/petsburgh/1975/flamingo.html
# 868
# http://animaldiversity.ummz.umich.edu/site/accounts/information/phoenicopterus_ruber.html
# 869
# http://www.mbr-pwrc.usgs.gov/id/framlst/i1820id.html
# 870
# http://animals.about.com/od/birds/p/greaterflamingo.htm
# 871
# http://www.stanford.edu/group/stanfordbirds/text/essays/flamingo_feeding.html
# 872
# http://bioweb.uwlax.edu/bio203/s2007/greaney_megh
# 873
# http://www.kenyabirds.org.uk/flamingo_g.htm
# 874
# http://www.kenyabirds.org.uk/flamingo_l.htm
# 875
# http://www.bbc.co.uk/nature/wildfacts/factfiles/3104.shtml
# 876
# http://www.montereybay.com/creagrus/woodpeckers.html
# 877
# http://montereybay.com/creagrus/barbets.html
# 878
# http://montereybay.com/creagrus/asian_barbets.html
# 879
# http://montereybay.com/creagrus/african_barbets.html
# 880
# http://animaldiversity.ummz.umich.edu/site/accounts/classification/piciformes.html
# 881
# http://pelotes.jea.com/animalfact/birds/woodpeck.htm
# 882
# http://www.kenyabirds.org.uk/barbet-wh.htm
# 883
# http://www.kenyabirds.org.uk/ry_barbet.htm
# 884
# http://www.honoluluzoo.org/red_and_yellow_barbet.htm
# 885
# http://www.kenyabirds.org.uk/d_barbet.htm
# 886
# http://www.kenyabirds.org.uk/tinker-rf.htm
# 887
# http://www.kenyabirds.org.uk/nubian_wp.htm
# 888
# http://www.juliezickefoose.com/articles/ivory_billed_wp.html
# 889
# http://www.museum.lsu.edu/~remsen/ibw.html
# 890
# http://www.rainforestconservation.org/data_sheets/birds/cc_woodpecker.html
# 891
# http://animaldiversity.ummz.umich.edu/site/accounts/sounds/campephilus_guatemalensis.html
# 892
# http://www.npr.org/templates/story/story.php?storyid=4622633
# 893
# http://www.sciencemag.org/cgi/content/abstract/1114103
# 894
# http://www.corante.com/loom/archives/2005/04/28/reports_of_my_extinction_are_greatly_exaggerated.php
# 895
# http://www.nature.org/ivorybill/
# 896
# http://www.ivorybill.org/
# 897
# http://www.fws.gov/ivorybill/
# 898
# http://www.ivorybills.blogspot.com/
# 899
# http://www.ibwo.org/
# 900
# http://www.ivory-bill-woodpecker.com/
# 901
# http://www.birds.cornell.edu/ivory/
# 902
# http://web2.uwindsor.ca/courses/biology/dmennill/ibwo/ibwoindex.php
# 903
# http://www.avesphoto.com/website/na/species/flkgil-1.htm
# 904
# http://www.nenature.com/northernflicker.htm
# 905
# http://www.mbr-pwrc.usgs.gov/id/framlst/i4140id.html
# 906
# http://www.mbr-pwrc.usgs.gov/id/framlst/i4050id.html
# 907
# http://www.mangoverde.com/birdsound/spec/spec104-167.html
# 908
# http://www.nenature.com/pileatedwoodpecker.htm
# 909
# http://www.pileatedwoodpeckercentral.com/
# 910
# http://birds.cornell.edu/bfl/speciesaccts/lewwoo.html
# 911
# http://www.focusonnature.com/puertoricanwoodpecker.htm
# 912
# http://www.landiss.com/woodpecker.htm
# 913
# http://www.mbr-pwrc.usgs.gov/id/framlst/i4110id.html
# 914
# http://www.birdphotography.com/species/giwo.html
# 915
# http://www.birdsofoklahoma.net/gfwoodpecker.htm
# 916
# http://www.arthurgrosset.com/sabirds/whitewoodpecker.html
# 917
# http://www.nenature.com/redheadedwoodpecker.htm
# 918
# http://www.nenature.com/redbelliedwoodpecker.htm
# 919
# http://animaldiversity.ummz.umich.edu/site/accounts/information/melanerpes_formicivorus.html
# 920
# http://www.birding.com/topbirds/572aw.asp
# 921
# http://www.birds.cornell.edu/allaboutbirds/birdguide/red-bellied_woodpecker_dtl.html
# 922
# http://www.birds.cornell.edu/allaboutbirds/birdguide/red-headed_woodpecker.html
# 923
# http://www.squirrelhouse.com/enter/birds/index.html
# 924
# http://rcwrecovery.fws.gov/
# 925
# http://www.wbu.com/chipperwoods/photos/downy.htm
# 926
# http://www.mbr-pwrc.usgs.gov/id/framlst/i3970id.html
# 927
# http://www.mbr-pwrc.usgs.gov/id/framlst/i3960id.html
# 928
# http://www.wbu.com/chipperwoods/photos/hwood.htm
# 929
# http://www.mbr-pwrc.usgs.gov/id/framlst/i3980id.html
# 930
# http://www.mbr-pwrc.usgs.gov/id/framlst/i4010id.html
# 931
# http://www.birdnature.com/bb3tw.html
# 932
# http://www.nenature.com/downywoodpecker.htm
# 933
# http://www.nenature.com/hairywoodpecker.htm
# 934
# http://birds.cornell.edu/bfl/speciesaccts/ariwoo.html
# 935
# http://animaldiversity.ummz.umich.edu/site/accounts/information/picoides_scalaris.html
# 936
# http://www.woodpeckersofeurope.info/
# 937
# http://www.birds.cornell.edu/allaboutbirds/birdguide/nuttalls_woodpecker_dtl.html
# 938
# http://biology.mhc.edu/ybsa/
# 939
# http://imnh.isu.edu/digitalatlas/bio/birds/wdpkrs/rnsa/rnsa_mai.htm
# 940
# http://www.stanfordalumni.org/birdsite/text/species/red-breasted_sapsucker.html
# 941
# http://www.birdphotography.com/species/rbsa.html
# 942
# http://www.mbr-pwrc.usgs.gov/id/framlst/i4021id.html
# 943
# http://www.nenature.com/yellowbelliedsapsucker.htm
# 944
# http://imnh.isu.edu/digitalatlas/bio/birds/wdpkrs/wisa/wisa_mai.htm
# 945
# http://www.birds.cornell.edu/allaboutbirds/birdguide/yellow-bellied_sapsucker.html
# 946
# http://bioweb.uwlax.edu/bio203/s2008/todd_ange/
# 947
# http://www.kenyabirds.org.uk/barb-bt.htm
# 948
# http://www.kenyabirds.org.uk/barb-sf.htm
# 949
# http://www.kenyabirds.org.uk/barb-rf.htm
# 950
# http://www.mbr-pwrc.usgs.gov/id/framlst/i0011id.html
# 951
# http://www.dnr.state.wi.us/org/land/er/factsheets/birds/rdnkgr.htm
# 952
# http://www.nenature.com/piedbilledgrebe.htm
# 953
# http://www.npwrc.usgs.gov/resource/birds/forest/species/podinigr.htm
# 954
# http://www.npwrc.usgs.gov/resource/birds/forest/species/podipodi.htm
# 955
# http://www.neseabirds.com/sheargreat.htm
# 956
# http://www.neseabirds.com/shearcory.htm
# 957
# http://www.neseabirds.com/shearwatermanx.htm
# 958
# http://www.neseabirds.com/shearwateraudubon.htm
# 959
# http://www.avesphoto.com/website/na/species/shwlit-1.htm
# 960
# http://www.austmus.gov.au/factsheets/wandering_albatross.htm
# 961
# http://www.shearwaterjourneys.com/shyalbatross.html
# 962
# http://www.neseabirds.com/stormpwsp.htm
# 963
# http://www.neseabirds.com/stormpetrelwf.htm
# 964
# http://www.seabirding.com/bpiimage.htm
# 965
# http://www.oceanwanderers.com/bermudapet.html
# 966
# http://www.borealforest.org/world/birds/short_tailed_shearwater.htm
# 967
# http://nzbirds.com/birds/bluepetrel.html
# 968
# http://www.avesphoto.com/website/na/species/petbcp-2.htm
# 969
# http://www.mbr-pwrc.usgs.gov/id/framlst/i1090id.html
# 970
# http://www.birdguides.com/species/species.asp?sp=011003
# 971
# http://nzbirds.com/birds/titi.html
# 972
# http://www.falklandsconservation.com/wildlife/albatross/black-browed-albatross.html
# 973
# http://www.falklandsconservation.com/wildlife/albatross/southern-giant-petrel.html
# 974
# http://www.falklandsconservation.com/wildlife/albatross/white-chinned-petrel.html
# 975
# http://www.parrotsinternational.org/
# 976
# http://www.netpets.com/birds/reference/lafeber/8/incredible_beak.html
# 977
# http://www.freeparrots.net
# 978
# http://hatchedtoflyfree.org/
# 979
# http://vtpb-www2.cvm.tamu.edu/brightsmith/
# 980
# http://www.cityparrots.org/
# 981
# http://www.nzbirds.com/birds/sulphurcrested.html
# 982
# http://papagaio2000.sites.uol.com.br/indexing.htm
# 983
# http://www.nepa.gov.jm/yourenv/biodiversity/species/black_billed.htm
# 984
# http://www.avesphoto.com/website/na/species/parrcr-1.htm
# 985
# http://www.oaklandzoo.org/meet_the_animals/yellow-naped-amazon-parrot*
# 986
# http://www.greatgreenmacaw.org/
# 987
# http://hatchedtoflyfree.homestead.com/
# 988
# http://www.bluemacaws.org/
# 989
# http://freespace.virgin.net/susan.armitage/macaws.htm
# 990
# http://www.macawlanding.org/
# 991
# http://vtpb-www2.cvm.tamu.edu/brightsmith/
# 992
# http://www.nzbirds.com/birds/kakarikiyellow.html
# 993
# http://nzbirds.com/birds/antipodesparakeet.html
# 994
# http://animaldiversity.ummz.umich.edu/site/accounts/information/nestor_notabilis.html
# 995
# http://www.nzbirds.com/birds/kea.html
# 996
# http://nzbirds.com/birds/kaka.html
# 997
# http://haryana-online.com/fauna/birds/alexandrine_parakeet.htm
# 998
# http://www.birdlife.org/datazone/species/index.html?action=spchtmdetails.asp&amp;sid=1530&amp;m=0
# 999
# http://www.kakapo.net/
# 1000
# http://en.wikipedia.org/wiki/kakapo
# 1001
# http://nzbirds.com/birds/kakapo.html
# 1002
# http://www.kakaporecovery.org.nz/
# 1003
# http://bioweb.uwlax.edu/bio203/s2008/runde_sama/
# 1004
# http://www.kenyabirds.org.uk/parrot-ob.htm
# 1005
# http://www.wingscentral.org/aps/faqcapes.aspx
# 1006
# http://www.wingscc.com/aps/poicep.htm
# 1007
# http://www.seabirds.org/penguins.htm
# 1008
# http://www.penguin.net.nz/
# 1009
# http://www.bluemoon.net/~opus/nframe/penguin.html
# 1010
# http://octopus.gma.org/surfing/antarctica/penguin.html
# 1011
# http://www.antarcticconnection.com/antarctic/wildlife/penguins/index.shtml
# 1012
# http://www.penguins.cl/
# 1013
# http://www.falklands.net/
# 1014
# http://englishnf.pinguins.info/
# 1015
# http://www.gdargaud.net/antarctica/penguins.html
# 1016
# http://www.adelie.pwp.blueyonder.co.uk/

# %%
label = []
for i in range(0,rows):
    label.append(1)

# %%
d={'Protocol':pd.Series(protocol),'Domain':pd.Series(domain),'Path':pd.Series(path),'Having_IP':pd.Series(having_ip),
   'URL_Length':pd.Series(len_url),'Having_@_symbol':pd.Series(having_at_symbol),
   'Redirection_//_symbol':pd.Series(redirection_symbol),'Prefix_suffix_separation':pd.Series(prefix_suffix_separation),
   'Sub_domains':pd.Series(sub_domains),'tiny_url':pd.Series(tiny_url),'web_traffic' : pd.Series(web_traffic) ,
   'domain_registration_length':pd.Series(domain_registration_length),'dns_record':pd.Series(dns_record),
   'statistical_report':pd.Series(statistical_report),'age_domain':pd.Series(age_domain),'http_tokens':pd.Series(http_tokens),
   'label':pd.Series(label)}
data=pd.DataFrame(d)
data
# Out:
#      Protocol                           Domain  ... http_tokens  label
# 0        http         www.liquidgeneration.com  ...           0      1
# 1        http              www.onlineanime.org  ...           0      1
# 2        http              www.ceres.dti.ne.jp  ...           0      1
# 3        http                   www.galeon.com  ...           0      1
# 4        http              www.fanworkrecs.com  ...           0      1
# ...       ...                              ...  ...         ...    ...
# 1012     http                  www.penguins.cl  ...           0      1
# 1013     http                www.falklands.net  ...           0      1
# 1014     http          englishnf.pinguins.info  ...           0      1
# 1015     http                 www.gdargaud.net  ...           0      1
# 1016     http  www.adelie.pwp.blueyonder.co.uk  ...           0      1
#
# [1017 rows x 17 columns]

# %%
data.to_csv("legitimate-urls.csv",index=False,encoding='UTF-8')

# %%
#data.to_csv("phishing-urls.csv",index=False,encoding='UTF-8')
